# %% [markdown]
# <h1 style="text-align: center;">Pitch Sequencing Model</h1>

# %% [markdown]
# ## Necessary Libraries

# %%
import pandas as pd
pd.options.display.max_columns = None

# %% [markdown]
# ## Loading in the Data

# %%
df = pd.read_csv("../../Files/pitch_class_trackman_games.csv").iloc[:, 1:].copy()
print(df.head())
# Out:
#    PitchNo        Date         Time  PAofInning  PitchofPA        Pitcher  \
# 0       16  2025-02-21  14:11:11.82           1          1  Walton, Ryker
# 1       18  2025-02-21  14:11:44.93           1          3  Walton, Ryker
# 2       20  2025-02-21  14:12:39.16           2          1  Walton, Ryker
# 3       21  2025-02-21  14:12:57.54           2          2  Walton, Ryker
# 4       22  2025-02-21  14:13:14.13           2          3  Walton, Ryker
#
#     PitcherId  PitcherThrows PitcherTeam             Batter  BatterId  \
# 0  10288839.0              1     EKU_COL  Sanford, Mitchell  689407.0
# 1  10288839.0              1     EKU_COL  Sanford, Mitchell  689407.0
# 2  10288839.0              1     EKU_COL         Hill, Luke  702619.0
# 3  10288839.0              1     EKU_COL         Hill, Luke  702619.0
# 4  10288839.0              1     EKU_COL         Hill, Luke  702619.0
#
#   BatterSide BatterTeam PitcherSet  Inning Top/Bottom  Outs  Balls  Strikes  \
# ...
